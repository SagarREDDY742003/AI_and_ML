# %%
int = 10
float = 3.12
str = "AI"
list = [1,5,3]
tuple = (4,7,6)
dict = {"name":"sagar","role":"developer"}
set = {7,8,9,1,2,3}
bool = True

# %%
print("int:", int)
print("float:", float)
print("str:", str)
list.append(4)
print("list:", list)
print("tuple:", tuple)
print("dict:", dict)
print("name:", dict["name"])
print("set:", set)
print("bool:", bool)
# Out:
# int: 10
# float: 3.12
# str: AI
# list: [1, 5, 3, 4]
# tuple: (4, 7, 6)
# dict: {'name': 'sagar', 'role': 'developer'}
# name: sagar
# set: {1, 2, 3, 7, 8, 9}
# bool: True

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry
