# %% [markdown]
# # 1️⃣ datetime Module (Work with Dates & Time)
#
# - Used for: Timestamps, Logging, Scheduling, Data analysis
#
# - Get current date and time
# ``` py
# from datetime import datetime
# now = datetime.now()
# print(now)
#
# # output: 2026-03-06 19:40:12
# ```
# - Get only today's date
# ``` py
# from datetime import date
# today = date.today()
# print(today)
# ```
# - Format date
# ``` py
# from datetime import datetime
# now = datetime.now()
# print(now.strftime("%d-%m-%Y"))
#
# #output: 06-03-2026
# ```
# - Common formats
#     - %Y: year
#     - %m: month
#     - %d: day
#     - %H: hour
#     - %M: minute
#
# # 2️⃣ math Module (Mathematical Functions)
#
# - Used for: scientific calculations, data analysis, geometry
#
# - Example
# ``` py
# import math
# print(math.sqrt(25))
# print(math.ceil(4.3))
# print(math.floor(4.9))
#
# # Output: 5, 5, 4
# ```
# - Important functions
#     - sqrt(): square root
#     - ceil(): round up
#     - floor(): round down
#     - pow(): power
#     - factorial(): factorial
#
# *3️⃣ random Module (Generate Random Values)*
# - Used in: games, simulations, OTP generation, testing
# - Random number
# ``` py
# import random
# print(random.randint(1,10))
# ```
# *Generates number between 1 and 10.*
# ``` py
# import random
# colors = ["red","blue","green"]
# print(random.choice(colors))
# ```
# - Shuffle list
# ``` py
# import random
# numbers = [1,2,3,4,5]
# random.shuffle(numbers)
# print(numbers)
# ```
#
# ### ✅ Practice Tasks Solutions:
#
# *1. Print current date and time*
# ``` py
# from datetime import datetime
# now = datetime.now()
# print(now)
# ```
# *2. Calculate square root of a number using math*
# ``` py
# import math
# num = 25
# print(math.sqrt(num))
# ```
# *3. Generate random number between 1-100*
# ``` py
# import random
# print(random.randint(1, 100))
# ```
# *4. Shuffle a list of names*
# ``` py
# import random
# names = ["John", "Alice", "Bob", "Eve"]
# random.shuffle(names)
# print(names)
# ```
# *5. Generate 6-digit OTP*
# ``` py
# import random
# otp = random.randint(100000, 999999)
# print("OTP:", otp)
# ```
# *Quick Memory Rules*
# - datetime → date & time
# - math → calculations
# - random → randomness

# %%
import pytz
import datetime

dt_utcnow = datetime.datetime.now(tz=pytz.timezone('Indian/Comoro'))
print(dt_utcnow)

# for tz in pytz.all_timezones:
    # print(tz)
# Out:
# 2026-03-12 13:42:54.992766+03:00

# %% [markdown]
# #### Refactor the provided Python code to improve its efficiency and readability while maintaining its functionality. The code calculates the number of weekdays between two dates using the datetime module.

# %%
from datetime import datetime

def count_weekdays(start_date, end_date):
    date_format = "%Y-%m-%d"
    start = datetime.strptime(start_date, date_format)
    end = datetime.strptime(end_date, date_format)

    # Total number of days (inclusive)
    total_days = (end - start).days + 1

    # Full weeks and remaining days
    full_weeks, extra_days = divmod(total_days, 7)

    # Each full week has 5 weekdays
    weekdays = full_weeks * 5

    # Count weekdays in the leftover days
    for i in range(extra_days):
        if (start.weekday() + i) % 7 < 5:  # 0–4 are weekdays
            weekdays += 1

    return weekdays

print(count_weekdays("2024-01-01", "2024-01-31"))  # 23 weekdays
print(count_weekdays("2024-03-01", "2024-03-10"))  # 6 weekdays
# Out:
# 23
# 6

# %% [markdown]
# # 1️⃣ os Module (Operating System Interaction)
#
# Used for:
# - Working with files and folders
# - Automation scripts
# - Getting system paths
#
# *Get current working directory*
# ``` py
# import os
# print(os.getcwd())
# ```
# *List files in a folder*
# ``` py
# import os
# print(os.listdir())
# ```
# *Create a new folder*
# ``` py
# import os
# os.mkdir("new_folder")
# ```
# *Check if file exists*
# ``` py
# import os
# print(os.path.exists("data.txt"))
# ```
# # 2️⃣ sys Module (System-Level Operations)
#
# Used for:
# - Accessing Python runtime info
# - Command-line arguments
# - System configuration
#
# *Check Python version*
# ``` py
# import sys
# print(sys.version)
# ```
# *Command line arguments*
# ``` py
# import sys
# print(sys.argv)
# ```
# Example run: `python script.py hello`
#
# Output: `['script.py', 'hello']`
#
# # 3️⃣ json Module (Data Exchange Format)
#
# JSON is widely used in: APIs Web applications Configuration files
#
# Example JSON `{ "name": "Deepak", "age": 25 }`
#
# *Convert Python → JSON*
# ``` py
# import json
# data = {"name": "Deepak", "age": 25}
# json_data = json.dumps(data)
# print(json_data)
# ```
# *Convert JSON → Python*
# ``` py
# import json
# json_string = '{"name":"Deepak","age":25}'
# data = json.loads(json_string)
# print(data["name"])
# ```
# *Save JSON to file*
# ``` py
# import json
# data = {"name":"Deepak","age":25}
# with open("data.json","w") as f:
#     json.dump(data,f)
# ```
# *Read JSON from file*
# ``` py
# import json
# with open("data.json","r") as f:
#     data = json.load(f)
# print(data)
# ```
# *Real Example: Config File Reader*
# ``` py
# import json
# with open("config.json") as f:
#     config = json.load(f)
# print(config["database"])
# ```
# Used heavily in real-world applications.
#
# ### ✅ Practice Task Solutions — Try it yourself first
#
# *Task 1. Print current working directory using os*
# ``` py
# import os
# current_dir = os.getcwd()
# print("Current Directory:", current_dir)
# ```
# *Task 2. List all files in current folder*
# ``` py
# import os
# files = os.listdir()
# for f in files:
#     print(f)
# ```
# *Task 3. Print Python version using sys*
# ``` py
# import sys
# print("Python Version:", sys.version)
# ```
# *Task 4. Convert dictionary to JSON string*
# ``` py
# import json
# data = { "name": "Deepak", "age": 25 }
# json_string = json.dumps(data)
# print(json_string)
# # Output example: `{"name": "Deepak", "age": 25}`
# ```
# *Task 5. Save JSON data into file*
# ``` py
# import json
# data = { "name": "Deepak", "age": 25 }
# with open("data.json", "w") as file:
#     json.dump(data, file)
# print("JSON saved successfully")
# ```

# %% [markdown]
# # Working with External Packages Part 1: pip & Virtual Environments
#
# ### 1️⃣ What is pip*
# pip = Python package manager. It installs external libraries from PyPI (Python Package Index).
#
# Example command:
# `pip install requests`
#
# After installing, you can use it in Python.
# import requests
#
# *2️⃣ Check installed packages*
#
# `pip list` Shows all installed libraries.
#
# *3️⃣ Check package information*
#
# `pip show requests`
#
# Displays: version, location, dependencies
#
# *4️⃣ Upgrade a package*
#
# `pip install --upgrade requests`
#
# *5️⃣ Uninstall a package*
#
# `pip uninstall requests`
#
# ### What is a Virtual Environment
#
# A virtual environment isolates project dependencies.
#
# Without virtual environments:
#
# - Project A → requests 2.25
# - Project B → requests 3.0
#
# Conflict occurs.
#
# Virtual environments solve this. Each project has its own packages.
#
# *7️⃣ Create a Virtual Environment*
#
# `python -m venv myenv`
#
# This creates a folder: myenv/
#
# *8️⃣ Activate Virtual Environment*
#
# - Windows: `myenv\Scripts\activate`
# - Mac/Linux: `source myenv/bin/activate`
#
# Terminal will show: `(myenv)`
#
# Now packages install only in this environment.
#
# *9️⃣ Install package inside environment*
#
# `pip install requests`
#
# *🔟 Deactivate environment*
# `deactivate`
#
# ✅ *Real Example*
#
# import requests
# response = requests.get("https://api.github.com")
# print(response.status_code)
#
# # Practice Task Solutions
#
# *Task 1. Check installed packages using pip list*
#
# Command: `pip list`
#
# Example output:
#
# Package    Version
# ------------ -------
# pip        23.0
# requests   2.31.0
# numpy      1.26.0
#
# Shows all installed Python libraries.
#
# *Task 2. Install requests package*
#
# Command: `pip install requests`
#
# After installation you can use it in Python:
#
# import requests
# response = requests.get("https://api.github.com")
# print(response.status_code)
#
# *Task 3. Create a virtual environment*
#
# Command: `python -m venv myenv`
#
# This creates a folder: myenv/
#
# Inside it Python creates isolated environment files.
#
# *Task 4. Activate virtual environment*
#
# - Windows: `myenv\Scripts\activate`
# - Mac/Linux: `source myenv/bin/activate`
#
# Terminal will show: `(myenv)`
#
# Now the environment is active.
#
# *Task 5. Install package inside virtual environment*
#
# Once environment is active:
# `pip install requests`
#
# Now the package installs only inside this environment.
#
# Deactivate environment
#
# `deactivate`
#
# Returns terminal to global Python environment.

# %%
from statistics import mode

print(mode([-1,1,1,2,3]))
# Out:
# 1

# %%
from random import *
# random
print(random())
# randint
print(randint(0,10))
# choice
print(choice(['sagar','basha','chiru','sutej']))
print(randrange(0,10,3))
# Out:
# 0.6685183969314846
# 4
# sagar
# 9

# %% [markdown]
# # Time and Date

# %%
import time

time.time()
# Out:
# 1772793152.660056

# %%
time.ctime()
# Out:
# 'Fri Mar  6 16:15:09 2026'

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=3, tm_mday=6, tm_hour=16, tm_min=17, tm_sec=51, tm_wday=4, tm_yday=65, tm_isdst=0)

# %%
time.mktime(time.localtime())
# Out:
# 1772794383.0

# %%
time.asctime(time.localtime())
# Out:
# 'Fri Mar  6 16:24:30 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=3, tm_mday=6, tm_hour=10, tm_min=55, tm_sec=58, tm_wday=4, tm_yday=65, tm_isdst=0)

# %%
time.strftime('%d/%m/%y')
# Out:
# '06/03/26'

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 3, 6, 16, 31, 36, 524917)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 3, 6, 16, 31, 25, 281758)

# %% [markdown]
# # Refactor the provided Python script to improve its efficiency and readability. The script calculates the number of weekends between two given dates using the datetime module. Consider edge cases and optimize the code for performance.
# from datetime import datetime, timedelta
#
# def count_weekends(start_date_str, end_date_str):
#
#     start_date = datetime.strptime(start_date_str, '%Y-%m-%d')
#
#     end_date = datetime.strptime(end_date_str, '%Y-%m-%d')
#
#     current_date = start_date
#
#     weekend_count = 0
#
#     while current_date <= end_date:
#
#         if current_date.weekday() in (5, 6):  # Saturday or Sunday
#
#             weekend_count += 1
#
#         current_date += timedelta(days=1)
#
#     return weekend_count

# %%
from datetime import datetime, timedelta
from typing import Union

def count_weekends(start_date_str: str, end_date_str: str) -> int:
    """
    Count the number of weekend days (Saturday and Sunday)
    between two given dates, inclusive.

    Args:
        start_date_str (str): Start date in 'YYYY-MM-DD' format.
        end_date_str (str): End date in 'YYYY-MM-DD' format.

    Returns:
        int: Number of weekend days between the two dates.
    """
    start_date = datetime.strptime(start_date_str, '%Y-%m-%d').date()
    end_date = datetime.strptime(end_date_str, '%Y-%m-%d').date()

    if start_date > end_date:
        raise ValueError("Start date must not be after end date.")

    # Total days in range
    total_days = (end_date - start_date).days + 1

    # Full weeks and remaining days
    full_weeks, extra_days = divmod(total_days, 7)

    # Each full week has exactly 2 weekend days
    weekend_count = full_weeks * 2

    # Handle leftover days beyond full weeks
    for i in range(extra_days):
        day = start_date + timedelta(days=full_weeks * 7 + i)
        if day.weekday() in (5, 6):  # Saturday=5, Sunday=6
            weekend_count += 1

    return weekend_count

print(count_weekends("2026-03-01", "2026-03-07"))  # Output: 2
print(count_weekends("2026-03-01", "2026-03-10"))  # Output: 4
print(count_weekends("2026-03-06", "2026-03-06"))  # Output: 1 (Friday → 0, Saturday → 1)
# Out:
# 2
# 3
# 0

# %% [markdown]
# # Refactor the provided script to improve its efficiency and error handling when installing packages from a requirements.txt file.
#
# import subprocess
#
# #### Function to install packages from requirements.txt
# def install_requirements(file_path):
#
#     with open(file_path, 'r') as file:
#
#         for line in file:
#
#             package = line.strip()
#
#             subprocess.run(['pip', 'install', package])
#
# #### Example usage
# install_requirements('requirements.txt')

# %%
import subprocess
import sys
from pathlib import Path

def install_requirements(file_path: str) -> None:
    """
    Install packages listed in a requirements.txt file.

    Args:
        file_path (str): Path to the requirements file.
    """
    req_file = Path(file_path)

    if not req_file.exists():
        raise FileNotFoundError(f"Requirements file not found: {file_path}")

    try:
        # Install all packages in one pip call for efficiency
        subprocess.run(
            [sys.executable, "-m", "pip", "install", "-r", str(req_file)],
            check=True
        )
        print("✅ All packages installed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"❌ Error occurred while installing packages: {e}")
    except Exception as e:
        print(f"⚠️ Unexpected error: {e}")

# Example usage
if __name__ == "__main__":
    install_requirements("requirements.txt")

# %%
import requests
import json

try:
    url = 'https://jsonplaceholder.typicode.com/todos'
    res = requests.get(url)
    data = res.json()
    
except Exception as e:
    print(e)

# %%
completed_todos = [todo for todo in data if todo['completed']]

for i in range(4):
    print(completed_todos[i]['title'])
# Out:
# et porro tempora
# quo adipisci enim quam ut ab
# illo est ratione doloremque quia maiores aut
# vero rerum temporibus dolor
